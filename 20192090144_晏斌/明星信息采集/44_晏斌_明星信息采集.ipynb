# %% [markdown]
# # 任务1：采集百度所有内地女明星的姓名、图片地址、目标网站链接。

# %%
#启动网页
import time,re,codecs
from selenium import webdriver
driver=webdriver.Chrome()
url = 'https://www.baidu.com/s?ie=utf-8&f=8&rsv_bp=1&rsv_idx=2&tn=baiduhome_pg&wd=%E6%98%8E%E6%98%9F&rsv_spt=1&oq=%25E6%2598%258E%25E6%2598%259F&rsv_pq=b3b20b9d0008adb7&rsv_t=6d8e54mTlJSgBzl0K5t2MlZxRuE%2BV7xPrnG6GBnfxV8ZifC%2F1o8k4GJC4ei0TghaM%2FWI&rqlang=cn&rsv_enter=0&rsv_dl=tb&rsv_sug3=1&rsv_sug1=1&rsv_sug7=100&prefixsug=%25E6%2598%258E%25E6%2598%259F&rsp=0&rsv_sug4=1518'
driver.get(url)
time.sleep(5)

#代码运行到“内地女明星”
driver.find_element_by_xpath("//div[@id='1']/div/div/div/div[2]/p/span[4]").click()#模拟点击“女”
time.sleep(2)
driver.find_element_by_xpath("//div[@id='1']/div/div/div/div[2]/p[2]/span[3]").click()#模拟点击“内地”

#等待并获取整个网页
time.sleep(1)
html = driver.page_source

#定位到“内地女明星信息框”
reobj = re.compile(r'<div class="c-border">[\s\S]*?下一页[\d\D]*?</div>', re.MULTILINE)
for match in reobj.finditer(html):
	match.group(0)

# %%
#开始爬取“姓名”、“图片地址”、“目标网址”信息
result=[]
while True:
        html = driver.page_source
        reobj = re.compile(r'<p class="op_exactqa_item_img"><a href="/s[\d\D]*?title="([\d\D]*?)"[\d\D]*?<img class="c-img c-img4" src="([\s\S]*?)"[\d\D]*?<p class="c-gap-top-small"><a href="([\d\D]*?)"', re.MULTILINE)
        for match in reobj.finditer(html):
            a=match.group(1)#姓名
            b=match.group(2)#图片地址
            c=match.group(3)#目标网址
            d=(a,b,c)#装进一个元组容器
            result.append(d)#列表打包（两层嵌套）
        time.sleep(1)
        html = driver.page_source
        if re.compile('<span class="opui-page-next OP_LOG_BTN" style="">下一页</span>', re.MULTILINE):#下一页
            driver.find_element_by_xpath("//div[@id='1']/div/div/div[2]/div[2]/p/span[6]").click()#没有下一页
        else:
            break
# Out:
# ---------------------------------------------------------------------------
# ElementNotVisibleException                Traceback (most recent call last)
# <ipython-input-2-35cc171ab15e> in <module>()
#      13         html = driver.page_source
#      14         if re.compile('<span class="opui-page-next OP_LOG_BTN" style="">下一页</span>', re.MULTILINE):
# ---> 15             driver.find_element_by_xpath("//div[@id='1']/div/div/div[2]/div[2]/p/span[6]").click()
#      16         else:
#      17             break
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementNotVisibleException: Message: element not visible
#   (Session info: chrome=79.0.3945.88)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 6.1.7601 SP1 x86_64)

# %% [markdown]
# # 代码的封装保存

# %%
#将采集的内容保存为CSV文件
import codecs
f = codecs.open(r"D:44_晏斌_明星.csv","w","utf-8-sig")
for i in result:
    f.write(",".join(i)+"\n")
f.close()
