# %%
from selenium import webdriver
import re,time
driver=webdriver.Chrome()
url = 'https://www.baidu.com/s?wd=%E6%98%8E%E6%98%9F&rsv_spt=1&rsv_iqid=0xbe4b76860031fb66&issp=1&f=8&rsv_bp=1&rsv_idx=2&ie=utf-8&rqlang=&tn=baiduhome_pg&ch=&rsv_enter=1&rsv_dl=ib&inputT=2978'
driver.get(url)
driver.find_element_by_xpath("//div[@id='1']/div/div/div/div[2]/p/span[4]").click()
driver.find_element_by_xpath("//div[@id='1']/div/div/div/div[2]/p[2]/span[3]").click()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-98a417257d53> in <module>
#       1 from selenium import webdriver
#       2 import re,time
# ----> 3 driver=webdriver.Chrome()
#       4 url = 'https://www.baidu.com/s?wd=%E6%98%8E%E6%98%9F&rsv_spt=1&rsv_iqid=0xbe4b76860031fb66&issp=1&f=8&rsv_bp=1&rsv_idx=2&ie=utf-8&rqlang=&tn=baiduhome_pg&ch=&rsv_enter=1&rsv_dl=ib&inputT=2978'
#       5 driver.get(url)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      71             service_args=service_args,
#      72             log_path=service_log_path)
# ---> 73         self.service.start()
#      74
#      75         try:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      97         while True:
#      98             self.assert_process_still_running()
# ---> 99             if self.is_connectable():
#     100                 break
#     101             count += 1
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\common\service.py in is_connectable(self)
#     113
#     114     def is_connectable(self):
# --> 115         return utils.is_connectable(self.port)
#     116
#     117     def send_remote_shutdown_command(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\common\utils.py in is_connectable(port, host)
#     104     socket_ = None
#     105     try:
# --> 106         socket_ = socket.create_connection((host, port), 1)
#     107         result = True
#     108     except socket.error:
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     714             if source_address:
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#     718             err = None
#
# KeyboardInterrupt:

# %%
tly = []
for i in range(335):
    html = driver.page_source
    reobj = re.compile(r"""title="([\d\D]*?)" target="_blank"><img class="c-img c-img4" src="([\d\D]*?)"></a></p>
                                        <p class="c-gap-top-small"><a href="([\d\D]*?) title="[\d\D]*?" target="_blank">[\d\D]*?</a></p>
""")
    for match in reobj.finditer(html):
        A = match.group(1)
        B = match.group(2)
        C = match.group(3)
        D = (A,B,C)
        tly.append(D)
    driver.find_element_by_xpath("//div[@id='1']/div/div/div[2]/div[2]/p/span[6]").click()

# %%
import codecs
f = codecs.open("D:\TLY.csv","w","utf-8-sig")
f.write("name,picture,interlinkage\n")
for i in tly:
   f.write(",".join(i)+"\n")
f.close()
