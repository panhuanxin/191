# %%
import re,time
from selenium import webdriver
driver = webdriver.Chrome()
url =  'https://map.baidu.com/search/%E9%85%92%E5%BA%97/@13401816.6,3523321.62,11.91z?querytype=nb&from=webmap&c=179&wd=%E9%85%92%E5%BA%97&pn=0&nn=0&db=0&sug=0&addr=0&pl_data_type=hotel&pl_sub_type=%E9%85%92%E5%BA%97&pl_price_section=0,%2B&pl_sort_type=default&pl_sort_rule=0&pl_discount2_section=0,%2B&pl_groupon_section=0,%2B&pl_cater_book_pc_section=0,%2B&pl_hotel_book_pc_section=0,%2B&pl_ticket_book_flag_section=0,%2B&pl_movie_book_section=0,%2B&pl_business_type=hotel&da_src=shareurl&on_gel=1&src=7&gr=3&l=11.911834556181791&uid=7a0cb8c0d67a634683a00c28&r=1000&device_ratio=2'
driver.get(url)
time.sleep(2)
list1 = []
while True:
    html = driver.page_source
    time.sleep(3)
    reobj = re.compile(r'title" data-detail-code="list_page">([\d\D]*?)</a>[\d\D]*?</i>([\d\D]*?)</span>')
    for match in reobj.finditer(html):
        a = match.group(1)
        b = match.group(2)
        c = (a,b)
        list1.append(c)
    reobj1 = re.compile(r'<a href="javascript:void\(0\)" tid="toNextPage"(.*)?">下一页&gt;</a>')
    for match in reobj1.finditer(html):
        a = match.group(1)
    if len(a)<30:
        break
    else:
        driver.find_element_by_link_text(u"下一页>").click()
        time.sleep(2)
print(list1)
# Out:
# [('TEL茶砚酒店', '舒适型                '), ('速8酒店(杭州下沙金沙居店)', '经济型                '), ('后街主题酒店', '经济型                '), ('贝壳酒店(学正街店)', '经济型                '), ('潮人旅馆', '经济型                '), ('微八主题酒店', '经济型                '), ('汉庭酒店(杭州下沙学正街店)', '经济型                '), ('怡梦宾馆', '经济型                '), ('家州旅馆', '经济型                '), ('杭州青芒酒店', '经济型                '), ('雅津宾馆', '经济型                '), ('高庭酒店(学正街店)', '经济型                '), ('杭州歌多酒店', '经济型                '), ('馨似家快捷酒店(下沙店)', '经济型                '), ('东运宾馆(下沙店)', '酒店                '), ('布丁严选酒店(下沙店)', '经济型                '), ('杭州轩鹏精选酒店(高沙学林街店)', '经济型                '), ('金昌宾馆', '经济型                '), ('全季酒店(下沙经济开发区店)', '舒适型                '), ('欣晨酒店', '酒店                '), ('派酒店(杭州下沙大学城文海南路地铁站店)', '经济型                '), ('祥平快捷酒店', '经济型                '), ('杭州酷我快捷酒店', '经济型                '), ('财林宾馆', '经济型                '), ('拓博精品酒店', '经济型                '), ('杭州歌江国际大酒店', '高档型                '), ('舒泊豪大酒店', '舒适型                '), ('汉庭酒店(高沙路地铁站店)', '经济型                '), ('枫林晚酒店(亚居店)', '经济型                '), ('亚居精品酒店', '宾馆                '), ('杭州迈捷酒店', '经济型                '), ('胜梦精品酒店', '经济型                '), ('聚缘商务酒店', '经济型                '), ('开心旅馆', '经济型                '), ('杭州和顺新亚洲美学精品酒店', '舒适型                '), ('杭州馨似家酒店公寓(十六街区店)', '经济型                '), ('福雷德·君喆酒店', '经济型                '), ('东运精品酒店(杭州下沙地铁江滨站店)', '经济型                '), ('沃居快捷酒店(下沙开发区及高教园店)', '经济型                '), ('一米酒店', '酒店                '), ('舒米酒店(下沙大学城店)', '经济型                '), ('优美快捷酒店', '经济型                '), ('杭州佑途主题酒店', '经济型                '), ('柳峰快捷酒店', '经济型                '), ('开火电竞轻奢酒店', '舒适型                '), ('速8酒店(学源店)', '经济型                '), ('锦江都城酒店(下沙店)', '舒适型                '), ('凯忆酒店连锁(高沙店)', '经济型                '), ('杭州呀诺达酒店', '经济型                '), ('华辰星光大酒店', '舒适型                '), ('7天酒店(高沙路地铁站店)', '经济型                '), ('柔娴快捷酒店', '经济型                '), ('吉情旅馆', '经济型                '), ('尚哈快捷酒店', '经济型                '), ('漫果主题酒店(杭州下沙店)', '经济型                '), ('古纳精品酒店', '经济型                '), ('锦江之星(高沙路地铁站店)', '经济型                '), ('星程酒店(金沙湖店)', '高档型                '), ('杭州恒寓智能酒店式公寓', '酒店                '), ('罗拉风情假日酒店(杭州下沙学源街店)', '经济型                '), ('如家酒店(文渊路传媒学院店)', '经济型                '), ('速8酒店(杭州下沙开发区店)', '经济型                '), ('方兴精品酒店', '经济型                '), ('7天酒店(杭州下沙大学城龙湖天街店)', '经济型                '), ('柠莱快捷酒店', '经济型                '), ('杭州铂宫酒店', '舒适型                '), ('学宁快捷酒店', '经济型                '), ('维也纳酒店(下沙店)', '舒适型                '), ('杭州德的酒店', '经济型                '), ('杭州随寓青年公寓酒店(杭州下沙高教园传媒学院店)', '经济型                '), ('杭州格桑花臻品酒店式公寓', '经济型                '), ('杭州娜迦酒店式公寓', '经济型                '), ('玖悦酒店', '经济型                '), ('南歌度假酒店公寓(杭州下沙和达城店)', '经济型                '), ('杭州云屋迷你酒店(下沙店)', '经济型                '), ('杭州百之引领酒店', '经济型                '), ('杭州财通酒店(下沙高沙路地铁站店)', '经济型                '), ('君阁商务酒店', '舒适型                '), ('爱巢主题酒店(杭州下沙店)', '酒店                '), ('杭州尚优客酒店(杭州下沙店)', '经济型                '), ('青瓷精品酒店式公寓', '经济型                '), ('杭州怡莱精品酒店(下沙店)', '经济型                '), ('杭州市金夜快捷酒店', '经济型                '), ('维也纳国际酒店(杭州火车东站店)', '舒适型                '), ('斯维特概念酒店(杭州东沙商业中心店)', '经济型                '), ('杭州天逅主题酒店(下沙大学城店)', '舒适型                '), ('盒子空间·澳枫酒店', '经济型                '), ('佑舍精品酒店(北苑大厦店)', '经济型                '), ('富邦国际大酒店', '四星级                '), ('锦江之星(萧山国际机场店)', '经济型                '), ('百时快捷酒店(杭州乐园店)', '经济型                '), ('杭州怡然之家酒店式公寓(学正街二十五号路口店)', '经济型                '), ('瑞莱克斯大酒店', '高档型                '), ('锦江之星(萧山杭州乐园店)', '经济型                '), ('杭州鼎御商务酒店(西湖店)', '经济型                '), ('漫步往事(玉泉店)', '经济型                '), ('维也纳国际酒店(杭州西湖文化广场地铁站店)', '舒适型                '), ('如家酒店(艮山西路店)', '经济型                '), ('如家酒店(朝晖路店)', '舒适型                '), ('莫泰酒店(杭州火车东站店)', '经济型                '), ('如家酒店(萧山长途汽车总站店)', '经济型                '), ('莫泰酒店(南宋御街步行街店)', '经济型                '), ( ...

# %%
with open("D:\02_学校周边酒店.csv","w",encoding="utf-8-sig") as f:
    f.write("酒店名称，酒店类型\n")
    for i in list1:
        f.write(i[0]+","+i[1]+","+"\n")
